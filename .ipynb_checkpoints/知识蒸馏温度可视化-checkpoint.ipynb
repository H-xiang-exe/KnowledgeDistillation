# %% [markdown]
# # 导入工具包

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 输入各类别Logits

# %%
logits = np.array([-5, 2, 7, 9])

# %% [markdown]
# # 普通softmax(T=1)

# %%
softmax_1 = np.exp(logits)/sum(np.exp(logits))

# %%
softmax_1
# Out:
# array([7.31819745e-07, 8.02537798e-04, 1.19107170e-01, 8.80089560e-01])

# %%
plt.plot(soft_max_1, label='softmax_1')

# %% [markdown]
# # 知识蒸馏softmax(T=3)

# %%
plt.plot(softmax_1, label = 'T=1')

T=3
softmax_2 = np.exp(logits/T)/sum(np.exp(logits/T))
plt.plot(softmax_2, label = 'T=3')

T=5
softmax_2 = np.exp(logits/T)/sum(np.exp(logits/T))
plt.plot(softmax_2, label = 'T=5')

T=10
softmax_2 = np.exp(logits/T)/sum(np.exp(logits/T))
plt.plot(softmax_2, label = 'T=10')

T=20
softmax_2 = np.exp(logits/T)/sum(np.exp(logits/T))
plt.plot(softmax_2, label = 'T=100')

plt.xticks(np.arange(4), ['Cat', 'Dog', 'Donkey', 'Horse'])
plt.legend()
plt.show()
